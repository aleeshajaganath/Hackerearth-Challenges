# %%
"""read csv file to write result"""

import pandas as pd
df=pd.read_csv("/media/aleeshasj/studies/Challenges/HCL ML Challenge/Results.csv")
df.head()
# print(df["Filename"]+".txt.html","\n")


import os
import numpy as np
import re 
path="f0230b3e675e11ea/HCL ML Challenge/Html/"
files=df["Filename"]#os.listdir(path)
# 23,000 -> 23000
# (23000) -> -23000
# (23,000) -> -23000
# {23000) or {23,000)
# x="(23000) "
def Decimal_fun(x):
    x=x.replace("___","")
    x=x.replace("-","nan")
    "remove space"
#     x=re.sub(r"\s+", "", x)
    
    p = re.compile(r'\W?[(]\d+,\d+\W?[)]|\W?[(]\d+[)]\W?')
    
    "as it is conditions"
    
    x=x.replace(",","")
    p = re.compile(r'\W?[(]\d+,\d+\W?[)]|\W?[(]\d+[)]\W?')
    # x.recompile()
    x=str(x)
    decimal=p.findall(x)
    if  (decimal!=[]):
        decimal[0]=decimal[0].replace("(","-")
        decimal[0]=decimal[0].replace(")","")
#         print(x,decimal[0])
        return(decimal[0])
#     x="{23000)"
    p = re.compile(r'\W?[{]\d+\d+\W?[)]')
    # x.recompile()
    decimal=p.findall(x)
    if  (decimal!=[]):
    #     decimal[0]=decimal[0].replace("(","-")
    #     decimal[0]=decimal[0].replace(")","")
#         print(x,decimal[0])
        return(x)
#     x="23,000"
    p = re.compile(r'\W?\d+,\d+\W?')
    # x.recompile()
    decimal=p.findall(x)
    if  (decimal!=[]):
        decimal[0]=decimal[0].replace(",","")
    #     decimal[0]=decimal[0].replace(")","")
#         print(x,decimal[0])
        return(decimal[0])

# files

# %%
x="(23000) "
Decimal_fun(x)
# p = re.compile(r'\W?[(]\s+\d+,\d+\W?[)]|\W?[(]\d+[)]\W?')
# p.findall(x)
# Out:
# '-23000 '

# %%
# print(df["Filename"]+".txt.html","\n")
def replace_x(x):
    x=x.replace("-","")
    x=x.replace("$","&#36")
    x=x.replace("€","&#8364")
    x=x.replace("£","&#163")
    return x
import json 
import os
import numpy as np
import re 
path="f0230b3e675e11ea/HCL ML Challenge/Html/"
files=df["Filename"]#+".txt.html"
count=0
string_check= re.compile('[£]|[€]') 
special_chara_found=0
break_from_all_files=0
files
import csv
with open("person.csv", 'a') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    spamwriter.writerow(["Filename", "Extracted","Values"])
    "for each file"
    for i in range(len(files)):#1):#
        dict={}
        no_lines=0
        temp1=[]#saving 's' ie all lines in list format
        confirm_year=0 #found the yar or not
        special_chara_found=0
        found_key_for_break=0
        found_2019=0
        len_only_digits=-1
#         files[i]="X8XX00LL"
        file1 = open(path+files[i]+".txt.html", 'r') 
        Lines = file1.readlines() 
        position=-1
        only_digits=[]
        
        print("\n ______________________________",count,files[i])
        for line in Lines: # read each line seperately
           
            if(line.strip()!='<br>' and line.strip()!=''):# eliminate these things
#                     no_lines=no_lines+1# count on lline number 
#                     splitted=line.strip().split(" ")#"remove space"
                    s=re.sub(' +', ' ',line.strip())# remove space  and save in s
#                     print(s)#,":",no_lines)
    
                    
#                     if(len_only_digits==2):
#                         break
                            
    
                       
                    """unwanted line eliminate"""
                    if(re.search("STATEMENTS", s, re.IGNORECASE)
                       or(found_key_for_break==1) or (re.search("SHAREHOLDERS", s))
                       or (confirm_year==1 and re.search("Notes", line.strip(), re.IGNORECASE)) ):
                        
                        print(len (dict),no_lines,"****************************")
                        print(dict)
                        if(len (dict)!=no_lines):
                            break_from_all_files=1
                        break;
                        
                    if(re.search("Capital and reserves", s) or re.search("reserves", s) or 
                       re.search("Reserves", s)):
                        
                               found_key_for_break=1
                               
                            
                        
                    """____________unwanted line eliminate___________"""
                    
#                     
                    
        
        
        
        
                    """create dictionary"""
                    
                    if(special_chara_found==1 ):
                                
                        
                               
                                no_lines=no_lines+1
#                                 print(no_lines)
                                print(s)
                        
 
#                                 p = re.compile(r'\W?\d+,\d+\W?|\W?\d+\W?')
#                                 p = re.compile(r'\W?\d+\W?\s+\W?\d+\W?$|[-]\s+\W?\d+\W?$|\W?\d+,\d+\W?\s\W?\d+,\d+\W?|\d\s\W?\d+,\d+\W?|[-]\s\W?\d+,\d+\W?|\W?\d+,\d+\W?\s[-]|\W?\d+\W?$|\W?\d+.\d+\W?\s+\W?\d+.\d+\W?$|\W?\d+\W?$')
#                                 p = re.compile(r'\W?\d+,\d+\W?|\W?\d+\W?\s+\W?\d+\W?$|[-]\s+\W?\d+\W?$|\W?\d+,\d+\W?\s\W?\d+,\d+\W?|\d\s\W?\d+,\d+\W?|[-]\s\W?\d+,\d+\W?|\W?\d+,\d+\W?\s[-]|\W?\d+\W?$|\W?\d+.\d+\W?\s+\W?\d+.\d+\W?$|\W?\d+\W?$')
#                                 p = re.compile(r'\W?\d+,\d+\W?|\W?\d+\W?\s+\W?\d+\W?$|\W?\d+\W?\s+[-]\W?$|[-]\s+\W?\d+\W?$|\W?\d+,\d+\W?\s\W?\d+,\d+\W?|\d\s\W?\d+,\d+\W?|[-]\s\W?\d+,\d+\W?|\W?\d+,\d+\W?\s[-]|\W?\d+\W?$|\W?\d+.\d+\W?\s+\W?\d+.\d+\W?$|\W?\d+\W?$')
                                "rhs"
                                p = re.compile(r'[-]\s+$|[-]$|\W?\s+\d+,\d+\s+\W?|\W?\s+\d+,\d+\W?|\W?\d+,\d+\s+\W?|\W?\d+,\d+\W?|\W?\d+\W?\s+\W?\d+\W?$|\W?\d+\W?\s+[-]\W?$|[-]\s+\W?\d+\W?$|\W?\d+,\d+\W?\s+\W?\d+,\d+\W?|\d\s\W?\d+,\d+\W?|[-]\s\W?\d+,\d+\W?|\W?\d+,\d+\W?\s[-]|\W?\d+\W?$|\W?\d+.\d+\W?\s+\W?\d+.\d+\W?$|\W?\d+\W?$')

                                decimal=p.findall(s)
            
                                
                                    
                                print(decimal)
#                                 print(decimal)
#                                 print()\D*[(][a-z]+[)]|\D*[(]
#                                 p = re.compile(r'\w+') 
#                                 phoneNumRegex= re.compile('\D*[(][a-z]+[)]|\D*[(]|\D+')  
#                                 phoneNumRegex = re.compile('\d+\D*\W?\d+\D*\W?\d+|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+')      
                                if(len_only_digits==2):
                                        #last
                                        phoneNumRegex = re.compile('\d+\D*\W?\d[.]\d+\D*\W?|[A-Z]+\D*|\d+\D*\W?\d+\D*\W?|\d+\D*\W?\d[.]\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      
            
#                                         phoneNumRegex = re.compile('[A-Z]+\D*|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      
    
#                                     phoneNumRegex = re.compile('[A-Z]+\D*|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      

#                                     phoneNumRegex = re.compile('[A-Z]+\D*|\d+\D*\W?\d+\D*\W?\d+|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      
                                else:
                                    y='\d+\D*\W?\d+\D*\W?\d'
                                    phoneNumRegex = re.compile(y)
                                    check=phoneNumRegex.findall(s)
                                    if(len(check)!=1):
                                        phoneNumRegex = re.compile('[A-Z]+\D*|\d+\D*\W?\d+\D*\W?\d+|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      
                                    else:
                                        phoneNumRegex = re.compile('[A-Z]+\D*|\d+\D*\W?\d+\D*\W?|\D*[(][a-z]+[)]|\D*[(]|\s+|\W?\d+\D*[a-z]+|\W?\d+\D*[a-z]+\W?\d+\D*[a-z]+|\W?\D*[a-z]+\W?\D*[a-z]+',re.IGNORECASE)      

#                                 phoneNumRegex = re.compile(r'(\D*)|\D*[(][a-z]+[)]') 
                                mo=phoneNumRegex.findall(s) 
#                                 print("mo",mo)
                                if(mo==[]):
                                    mo.append("nan")
                                x=mo [0]
                                
#                                 print("replace",x)
                                
                                """trim spaces"""
                                x=re.sub(r"^\s+|\s+$", "", x)
#                                 print("x:",re.search('[(]$', x))
#                                 check = re.compile('\D*[(]') 
#                                 check_list=check.findall(m[0])
                                if(re.search('[(]$', x)!=None):
    
                                    x=x.split("(")[0]
#                                     print(x)
#                                  print(s,":",no_lines)

#                                 x=re.sub(r"^\s+|\s+$", "", x)
#                                 print("sub",x)
#                                 "print the amount by position"
                                if(x==""):
                                            x="nan"
                                else:
                                    x=replace_x(x)  
                                print(x)
                                if(decimal==[]):
                                    decimal="nan"
                                    x=x.replace("-","")
                                    dict1 = {x:"nan"} 
                                    dict.update(dict1)
#                                     print(dict)
                                    
            
                                else:    
                                    if(found_2019!=1):
                                        decimal="nan"
                                        x=x.replace("-","")
                                        dict1 = {x:"nan"} 
                                        dict.update(dict1)
                                    else:#"found 2019"
                                        
                                        if(len_only_digits==1 ):
                                            decimal=Decimal_fun(decimal[0])
                                            dict1 = {x:decimal}
                                            dict.update(dict1)
#                                         else:
                        
                                        if(len_only_digits==2 ):
#                                       
                                            decimal=re.sub(r"^\s+|\s+$", "", decimal[0])#remove side spaces
#                                             print(x,":",am,":",no_lines)
                                            print(decimal)
#                                             print(am.split(" "))
                                            digits=decimal.split(" ")
                                            if(len(digits)==2):
        #                                             print(digits)
        #                                          
        #                                             digits[position]=digits[position].replace("-","nan")
        #                                         
                                                    decimal=Decimal_fun(digits[position])
        #                                           
                                                    
        #                                             print(decimal)
                    
                                            else:
                                                decimal=p.findall(s)
                                                digits=decimal[0].split(" ")
                                                if(len(digits)==2):
        #                                             print(digits)
        #                                          
        #                                             digits[position]=digits[position].replace("-","nan")
        #                                         
                                                    decimal=Decimal_fun(digits[position])
#                                                 print(decimal)
                                            dict1 = {x:decimal} 
                                            dict.update(dict1)
# #                                                 break
                    
                    
                    
                                        
                                    
                                        
                            
#                                 else:
# #                                     print("nan")
# #                                     x.replace("$","&#36")
# #                                     x.replace("€","&#8364")
# #                                     x.replace("£","&#163")
#                                     x=x.replace("-","")
#                                     x=x.replace("___","")
#                                     dict1 = {x:"nan"} 
#                                     dict.update(dict1)
#                                     print("nan")
#                                     print(x)
                                    
                                
#                                 continue



        
                    
                    "check for special chara"
                    if(string_check.search(line) != None and special_chara_found!=1 ): 
                    
                        special_chara_found=1 
                        
#                                 print("find special chara",count)



                        
                        "find the year from previous string"

                        string=temp1[len(temp1)-1].split(" ")
                        p = re.compile('20\d+') 
                        only_digits=p.findall(temp1[len(temp1)-1])
                        print(only_digits)
                        len_only_digits=len(only_digits)
#                         print("only digits",only_digits) 
#                         break
                        a=p.findall(temp1[len(temp1)-1])
                        value='2019'
                        confirm_year=1
                        
#                         print("2019 present",'2019' in p.findall(temp1[len(temp1)-1]))
#                         if(len(only_digits)>1):
                        if('2019' in p.findall(temp1[len(temp1)-1])) :
                                position=a.index(value)
#                                 print("2019 present",position)
                                found_2019=1
                            
                           
                        

                    temp=line.strip() #previous line
                    temp1.append(s)
#                     print(temp1)
                    """import json

                        with open('path_to_file/person.json') as f:
                          data = json.load(f)
                        """
        
                
        count=count+1
        if(break_from_all_files==1):
                   break
       
#         with open('person.csv', 'w') as json_file:
        js=json.dumps(dict)
#         import csv
#         with open('innovators.csv', 'a', newline='') as file:
#             writer = csv.writer(file)
#             writer.writerow([files[i],js])
       
#         person_dict = json.loads(person)
#         spamwriter.writerow([files[i],json.loads(dict)])
# Out:
#  ______________________________ 0 X8XUG1JD
# ['2019', '2018']
# Current Assets 312 1
# [' 312 1']
# Current Assets
# 312 1
# Creditors: amounts falling due within one year (59) -
# ['(59) -']
# Creditors: amounts falling due within one year
# (59) -
# Net current assets (liabilities) 253 1
# [' 253 1']
# Net current assets (liabilities)
# 253 1
# Total assets less current liabilities 253 1
# [' 253 1']
# Total assets less current liabilities
# 253 1
# Total net assets (liabilities) 253 1
# [' 253 1']
# Total net assets (liabilities)
# 253 1
# Capital and reserves 253 1
# [' 253 1']
# Capital and reserves
# 253 1
# 6 6 ****************************
# {'Current Assets': None, 'Total net assets (liabilities)': None, 'Net current assets (liabilities)': None, 'Creditors: amounts falling due within one year ': '-59', 'Capital and reserves': None, 'Total assets less current liabilities': None}
#
#  ______________________________ 1 X8XX0C57
# ['2020', '2019']
# ...

# %%
decimal=[]
if(decimal==[]):
    print(len(decimal))

# %%
x="100 Ordinary Shares of £ | each 100 100"
32 X8XZICIB
95 X8Y2EY7M
same key match
# Out:
# 0

# %%
x='(59)'
x='44'
p = re.compile(r'[(]\d+[)]')
# if(p.findall(x)==[]):
#     p.findall(x)
p.findall(x)
# Out:
# []

# %%
X8XX02AX
X8XX0ANN
8 X8XX00MX
17 X8XX02N7
"7 X8XX00LL","51 X8XZIKOX",69 X8XZIR1E,91 X8Y2ESK2
58 X8XZIO5G
64 X8XZIPBM
65 X8XZIPGP
 ___
90 X8Y2ESJM
decimal
0 X8XUG1JD:Creditors: amounts falling due within one year (59) -

# %%
import pandas as pd
check=pd.read_csv("/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results.csv")
check.shape
check.head(2)
# Out:
#    Filename  Extracted Values
# 0  X8XUG1JD               NaN
# 1  X8XX0C57               NaN

# %%
for i in range(check["Extracted Values"].shape)
# Out:
# (500,)

# %%
data = [('Bus Number', 'MW'),
        ('3', '20.4'),
        ('4', '20.5')]
# row 3, column 2

data[2][1] = '20.6'

writer = csv.writer(open('generation.csv', 'wb'))
writer.writerows(data)

# %%
# f1 = open ("/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results2.csv","r") # open input file for reading

# with open('/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results1.csv', 'wb') as f: # output csv file
#     writer = csv.writer(f)
#     with open('/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results.csv','r') as csvfile: # input csv file
#         reader = csv.reader(csvfile, delimiter=',')
#         for row in reader: 
#             if(row[1]=="Extracted Values"):
#                 continue
#             row[1]=f1.readline()
# #             print(row[0])
#             writer.writerow(row)

# %%
import html
print(html.unescape('&pound;682m'))
# Out:
# £682m

# %%
f1 = open ("/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results2.csv","r") # open input file for reading

with open('/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results.csv', 'wb') as f: # output csv file
    writer = csv.writer(f)
    with open('/media/aleeshasj/Os/HCL ML Challenge/HCL ML Challenge/Results1.csv','r') as csvfile: # input csv file
        reader = csv.reader(csvfile, delimiter=',')
        for row in reader:  
            row[7] = f1.readline() # edit the 8th column 
            writer.writerow(row)
f1.close()

# %%
reader

# %%
import pandas as pd
check=pd.read_csv("files/person.txt")
check.shape
# for i in check["Extracted"]:
#     print(type(i))
# Out:
# (0, 3)

# %%
import csv
person = '{"name": "Bob", "languages": ["English", "Fench"]}'
person_dict = json.loads(person)
with open("files/person_.csv", 'a') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    spamwriter.writerow(["Filename", "Extracted","Values"])
    spamwriter.writerow(['xxxx',json.loads(person)])
import pandas as pd
check=pd.read_csv("files/person_.csv")
check["Extracted"]
# Out:
# 0    {'languages': ['English', 'Fench'], 'name': 'B...
# 1                                            Extracted
# 2    {'languages': ['English', 'Fench'], 'name': 'B...
# 3                                            Extracted
# 4    {'languages': ['English', 'Fench'], 'name': 'B...
# Name: Extracted, dtype: object

# %%
person = '{"name": "Bob", "languages": ["English", "Fench"]}'
person_dict = json.loads(person)
type(person_dict)
# Out:
# dict

# %%
dict = {'Python' : '.py', 'C++' : '.cpp', 'Java' : '.java'}
f = open("files/dict.txt","w")
f.write( str(dict) )
f.close()

# %%
check.head()
# Out:
#   Filename                         Extracted  Values
# 0      foo  [{'bar': ['baz', None, 1.0, 2]}]     NaN

# %%
type(check["Filename"][0]
    )
# Out:
# str

# %%
type(check["Extracted"][0])
# Out:
# str

# %%
import json
json.loads('["foo", {"bar":["baz", null, 1.0, 2]}]')

# %%
y=" 200"
x=re.sub(r"^\s+|\s+$", "", x)

# %%
x
# Out:
# '200'
